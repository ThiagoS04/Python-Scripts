# %% [markdown]
# # Initial Data Cleaning
#
# Often your dataset has to be cleaned before you can do any analysis on it.  Some common data cleaning activities are included below.

# %%
import pandas as pd
datafile = "C:/Users/Nancy/Documents/Python Scripts/weather.csv"
df = pd.read_csv(datafile, index_col=2,parse_dates=True)

# %% [markdown]
# ### Column Names
#
# Sometimes the dataset has more data than what you need.  Remove any excess data.

# %%
df.columns
# Out:
# Index(['STATION', 'NAME', 'DAPR', 'MDPR', 'PRCP', 'SNOW', 'SNWD', 'TAVG',
#        'TMAX', 'TMIN', 'TOBS', 'WT01', 'WT02', 'WT06', 'WT08', 'WT09'],
#       dtype='object')

# %%
df.drop(axis=1, columns=['WT01', 'WT02', 'WT06', 'WT08', 'WT09'])
# Out:
#                 STATION                         NAME  DAPR  MDPR  RAIN  SNOW  \
# DATE
# 2022-01-01  US1NJOC0058  STAFFORD TWP 2.8 NNW, NJ US   NaN   NaN  0.17   NaN
# 2022-01-02  US1NJOC0058  STAFFORD TWP 2.8 NNW, NJ US   NaN   NaN  0.36   NaN
# 2022-01-03  US1NJOC0058  STAFFORD TWP 2.8 NNW, NJ US   NaN   NaN  0.02   0.0
# 2022-01-04  US1NJOC0058  STAFFORD TWP 2.8 NNW, NJ US   NaN   NaN  0.84   8.0
# 2022-01-05  US1NJOC0058  STAFFORD TWP 2.8 NNW, NJ US   NaN   NaN  0.02   NaN
# ...                 ...                          ...   ...   ...   ...   ...
# 2022-01-24  US1NJOC0090     PINE BEACH 0.4 NW, NJ US   NaN   NaN  0.00   0.0
# 2022-01-25  US1NJOC0090     PINE BEACH 0.4 NW, NJ US   NaN   NaN  0.00   0.0
# 2022-01-26  US1NJOC0090     PINE BEACH 0.4 NW, NJ US   NaN   NaN  0.00   0.0
# 2022-01-27  US1NJOC0090     PINE BEACH 0.4 NW, NJ US   NaN   NaN  0.00   0.0
# 2022-01-28  US1NJOC0090     PINE BEACH 0.4 NW, NJ US   NaN   NaN  0.00   0.0
#
#             SNWD  TAVG  TMAX  TMIN  TOBS
# DATE
# 2022-01-01   NaN   NaN   NaN   NaN   NaN
# 2022-01-02   NaN   NaN   NaN   NaN   NaN
# 2022-01-03   0.0   NaN   NaN   NaN   NaN
# 2022-01-04   8.0   NaN   NaN   NaN   NaN
# 2022-01-05   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...
# 2022-01-24   0.0   NaN   NaN   NaN   NaN
# 2022-01-25   0.0   NaN   NaN   NaN   NaN
# 2022-01-26   0.0   NaN   NaN   NaN   NaN
# 2022-01-27   0.0   NaN   NaN   NaN   NaN
# 2022-01-28   0.0   NaN   NaN   NaN   NaN
#
# [6362 rows x 11 columns]

# %% [markdown]
# #### Column names are sometimes cryptic, long, or difficult to work with.  Renaming them makes working with them easier.

# %%
df.rename(
    columns=({ 'PRCP': 'RAIN'}), 
    inplace=True,
)
df.columns
# Out:
# Index(['STATION', 'NAME', 'DAPR', 'MDPR', 'RAIN', 'SNOW', 'SNWD', 'TAVG',
#        'TMAX', 'TMIN', 'TOBS', 'WT01', 'WT02', 'WT06', 'WT08', 'WT09'],
#       dtype='object')

# %%
df.rename(columns=str.lower).head()
# Out:
#                 station                         name  dapr  mdpr  rain  snow  \
# DATE
# 2022-01-01  US1NJOC0058  STAFFORD TWP 2.8 NNW, NJ US   NaN   NaN  0.17   NaN
# 2022-01-02  US1NJOC0058  STAFFORD TWP 2.8 NNW, NJ US   NaN   NaN  0.36   NaN
# 2022-01-03  US1NJOC0058  STAFFORD TWP 2.8 NNW, NJ US   NaN   NaN  0.02   0.0
# 2022-01-04  US1NJOC0058  STAFFORD TWP 2.8 NNW, NJ US   NaN   NaN  0.84   8.0
# 2022-01-05  US1NJOC0058  STAFFORD TWP 2.8 NNW, NJ US   NaN   NaN  0.02   NaN
#
#             snwd  tavg  tmax  tmin  tobs  wt01  wt02  wt06  wt08  wt09
# DATE
# 2022-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-01-02   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-01-03   0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-01-04   8.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-01-05   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN

# %%
df.columns
# Out:
# Index(['STATION', 'NAME', 'DAPR', 'MDPR', 'RAIN', 'SNOW', 'SNWD', 'TAVG',
#        'TMAX', 'TMIN', 'TOBS', 'WT01', 'WT02', 'WT06', 'WT08', 'WT09'],
#       dtype='object')

# %% [markdown]
# ## Missing data
# Datasets often contain missing data. pandas has many functions to easily process data that is NaN (not a number).

# %%
import statistics as stats

# %%
stats.mean(df['PRCP'])
# Out:
# nan

# %%
df['PRCP'] = df['PRCP'].fillna(0)

# %%
stats.mean(df['PRCP'])
# Out:
# 0.11419207796290474
